# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def k_armed(k):
    mean_rewards = np.random.normal(size=k)
    bandit_rewards = []
    for bandit in range(k):
        rewards = np.random.normal(size=200)
        bandit_rewards.append(rewards)
    return bandit_rewards
        
        
def plot(bandit_rewards):
    sns.violinplot(x=np.arange(len(b)), data=b)
    plt.show()

# %%
b = k_armed(10)
plot(b)

# %%
b
# Out:
# [array([ 0.92043909, -0.56991723, -1.08628068,  1.27901882,  0.36148227,
#          0.09343373,  0.23279578,  1.00900833, -0.12559773,  0.52802191,
#          0.11114298,  0.97564974, -1.66999755,  1.05821546, -1.43077215,
#          0.28195293,  1.42021968,  0.55422945, -0.26705923, -0.42398469,
#          0.45343318, -0.91189616,  1.50537884, -1.66677708,  0.77019638,
#          0.95994768,  2.02380338,  0.58241137,  0.56908272,  1.21322423,
#          0.56464063, -1.00964561,  1.22134998, -0.24668131, -0.02999148,
#          0.70763595,  0.95889044, -0.72936087, -1.51042917, -1.50400904,
#          0.78587515, -1.40563709, -0.2721194 , -0.70483289,  1.40790243,
#         -0.32611454, -1.25818966,  0.55338936, -0.91102757,  0.01748815,
#          0.23638913,  0.10119541,  0.83647818,  0.87590747,  0.52477803,
#          1.40381405, -0.80608283, -0.55925587,  0.34916217, -0.48009867,
#          2.27002042,  0.25372349, -0.47502503, -0.70431754, -2.27588251,
# ...
